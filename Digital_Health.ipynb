# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipesh1123/DIGNIFIED-MENSTRUATION-CHATBOT/blob/main/Digital_Health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA IMPORT

# %%
import pandas as pd

file_path_excel = "/content/KNOWLEDGE ON DIGITAL HEALTH AND ITS ASSOCIATED FACTORS AMONG UNDERGRADUATE PUBLIC HEALTH STUDENTS (Responses).xlsx"
df = pd.read_excel(file_path_excel)

# Display the first few rows of the DataFrame to check if it loaded correctly
display(df.head())
# Out:
#                 Timestamp Would you like to participate in this research?   \
# 0 2025-08-26 12:24:53.624                                              Yes
# 1 2025-08-26 12:26:36.762                                              Yes
# 2 2025-08-26 12:31:23.316                                              Yes
# 3 2025-08-26 12:36:52.274                                              Yes
# 4 2025-08-26 12:43:12.639                                              Yes
#
#             1. Name:  2. Age 3. Gender  \
# 0   Abhishek Tiwari       24      Male
# 1       Bijeta singh      24    Female
# 2  Sushma Khatiwada       24    Female
# 3        Puja Bhatta      20    Female
# 4    Mahesh Bhandari      25      Male
#
#   4. Name of University (eg. Purbanchal University)  \
# 0                            Purbanchal university
# 1                            Purbanchal university
# 2                            Purbanchal university
# 3                             Tribhuvan University
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 39 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                                                                252 non-null    datetime64[ns]
#  1   Would you like to participate in this research?                                                                                                                          275 non-null    object
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# Remove the first two columns
df = df.drop(columns=df.columns[:2])

# Display the first few rows of the modified DataFrame
display(df.head())
# Out:
#             1. Name:  2. Age 3. Gender  \
# 0   Abhishek Tiwari       24      Male
# 1       Bijeta singh      24    Female
# 2  Sushma Khatiwada       24    Female
# 3        Puja Bhatta      20    Female
# 4    Mahesh Bhandari      25      Male
#
#   4. Name of University (eg. Purbanchal University)  \
# 0                            Purbanchal university
# 1                            Purbanchal university
# 2                            Purbanchal university
# 3                             Tribhuvan University
# 4                            Purbunchal University
#
#                                5. Parental Education  \
# 0  One parent has completed secondary education (+2)
# 1  Both parents has completed secondary education...
# 2  One parent has completed secondary education (+2)
# 3  Neither parent has completed secondary educati...
# 4  Neither parent has completed secondary educati...
#
#   6. Place of residence (Permanent) 7. Family Monthly Income  \
# ...

# %%
# Remove the numbering from the column names
df.columns = df.columns.str.replace(r'\d+\.\s+', '', regex=True)

# Display the updated column names to verify the changes
display(df.head())
# Out:
#                Name:  Age  Gender  \
# 0   Abhishek Tiwari    24    Male
# 1       Bijeta singh   24  Female
# 2  Sushma Khatiwada    24  Female
# 3        Puja Bhatta   20  Female
# 4    Mahesh Bhandari   25    Male
#
#   Name of University (eg. Purbanchal University)  \
# 0                         Purbanchal university
# 1                         Purbanchal university
# 2                         Purbanchal university
# 3                          Tribhuvan University
# 4                         Purbunchal University
#
#                                   Parental Education  \
# 0  One parent has completed secondary education (+2)
# 1  Both parents has completed secondary education...
# 2  One parent has completed secondary education (+2)
# 3  Neither parent has completed secondary educati...
# 4  Neither parent has completed secondary educati...
#
#   Place of residence (Permanent) Family Monthly Income Education Background  \
# ...

# %% [markdown]
# # DESCRIPTIVE ANALYSIS (SOCIO-DEMOGRAPHIC)

# %%
# Define the age bins and labels
age_bins = [15, 20, 25, 30, 35]
age_labels = ['15-19', '20-24', '25-29', '30-34']

# Create the 'Age_Category' column
df['Age_Category'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Calculate frequency of each age category
age_category_frequency = df['Age_Category'].value_counts()

# Display the age category frequency
display("Frequency of Age Category:")
display(age_category_frequency)
# Out:
# 'Frequency of Age Category:'
# Age_Category
# 20-24    194
# 25-29     49
# 15-19     16
# 30-34     16
# Name: count, dtype: int64

# %%
# Calculate the mean of the 'Age' column
mean_age = df['Age'].mean()

# Display the mean age
display(f"Mean age: {mean_age}")
# Out:
# 'Mean age: 23.29090909090909'

# %%
columns_to_analyze = [
    'Gender',
    'Parental Education',
    'Place of residence (Permanent)',
    'Family Monthly Income',
    'Education Background',
    'Academic Year'

]

for column in columns_to_analyze:
    if column in df.columns:
        display(f"Frequency of {column}:")
        display(df[column].value_counts())
    else:
        print(f"Column '{column}' not found in the DataFrame.")
# Out:
# 'Frequency of Gender:'
# Gender
# Female    162
# Male      113
# Name: count, dtype: int64
# 'Frequency of Parental Education:'
# Parental Education
# Both parents has completed secondary education or higher    97
# One parent has completed secondary education (+2)           91
# Neither parent has completed secondary education (+2)       87
# Name: count, dtype: int64
# 'Frequency of Place of residence (Permanent):'
# Place of residence (Permanent)
# Municipality             151
# Rural Municipality        65
# Sub-Metropolitan city     30
# Metropolitan city         29
# Name: count, dtype: int64
# 'Frequency of Family Monthly Income:'
# Family Monthly Income
# 30,000+            192
# 20,000 - 29,999     48
# 10,000 - 19,999     23
# < 9,999             12
# Name: count, dtype: int64
# 'Frequency of Education Background:'
# Education Background
# +2 science                                                           209
# ...

# %%
df['Name of University (eg. Purbanchal University)'].sort_values().unique()
# Out:
# array(['...', 'Institute of Medicine ', 'KAHS', 'KAHS,Jumla',
#        'Karbali academy of health sciences ',
#        'Karnali Academy Of Health Education ',
#        'Karnali Academy Of Health Science',
#        'Karnali Academy of Health Science ',
#        'Karnali Academy of Health Science jumla',
#        'Karnali Academy of Health Sciences',
#        'Karnali Academy of Health Sciences ',
#        'Karnali Academy of health sciences ',
#        'Karnali academic of health science ',
#        'Karnali academy of Health science ',
#        'Karnali academy of health science ',
#        'Karnali academy of health sciences',
#        'Karnali academy of health sciences ',
#        'Koshi Health and Science Campus ',
#        'Koshi health and science campus',
#        'Koshi health and science campus ', 'MBAHS', 'MMIHS, TU',
#        'Madan Bhandari Academy of Health Science',
#        'Madan Bhandari Academy of Health Science ',
# ...

# %%
university_mapping = {
    # KAHS
    "KAHS": "Karnali Academy of Health Sciences",
    "KAHS'": "Karnali Academy of Health Sciences",
    "KAHS,Jumla": "Karnali Academy of Health Sciences",
    "Karbali academy of health sciences ": "Karnali Academy of Health Sciences",
    "Karnali Academy Of Health Education ": "Karnali Academy of Health Sciences",
    "Karnali Academy Of Health Science": "Karnali Academy of Health Sciences",
    "Karnali Academy of Health Science ": "Karnali Academy of Health Sciences",
    "Karnali Academy of Health Science jumla": "Karnali Academy of Health Sciences",
    "Karnali Academy of Health Sciences": "Karnali Academy of Health Sciences",
    "Karnali Academy of Health Sciences ": "Karnali Academy of Health Sciences",
    "Karnali Academy of health sciences ": "Karnali Academy of Health Sciences",
    "Karnali academic of health science ": "Karnali Academy of Health Sciences",
    "Karnali academy of Health science ": "Karnali Academy of Health Sciences",
    "Karnali academy of health science ": "Karnali Academy of Health Sciences",
    "Karnali academy of health sciences": "Karnali Academy of Health Sciences",
    "Karnali academy of health sciences ": "Karnali Academy of Health Sciences",

    # TU
    "Institute of Medicine ": "Tribhuvan University",
    "TU": "Tribhuvan University",
    "Tu": "Tribhuvan University",
    "Tribhuvan Universiry": "Tribhuvan University",
    "Tribhuvan University": "Tribhuvan University",
    "Tribhuvan University ": "Tribhuvan University",
    "Tribhuvan university ": "Tribhuvan University",
    "Tribhuwan University ": "Tribhuvan University",
    "Tribhuwan university ": "Tribhuvan University",
    "MMIHS, TU": "Tribhuvan University",
    "kathmandu university": "Tribhuvan University",

    # PU / Purbanchal
    "...": "Purbanchal University",
    "PU": "Purbanchal University",
    "PU ": "Purbanchal University",
    "Pu": "Purbanchal University",
    "Purananchal university ": "Purbanchal University",
    "Purba chai University": "Purbanchal University",
    "Purbanchal": "Purbanchal University",
    "Purbanchal ": "Purbanchal University",
    "Purbanchal Jniversity": "Purbanchal University",
    "Purbanchal University": "Purbanchal University",
    "Purbanchal University ": "Purbanchal University",
    "Purbanchal Univery": "Purbanchal University",
    "Purbunchal University ": "Purbanchal University",
    "Purwanchal University": "Purbanchal University",
    "Purwanchal university ": "Purbanchal University",
    "Koshi Health and Science Campus ": "Purbanchal University",
    "Koshi health and science campus": "Purbanchal University",
    "Koshi health and science campus ": "Purbanchal University",
    "PU School of Health Sciences ": "Purbanchal University",
    "PUSH": "Purbanchal University",
    "Pushs": "Purbanchal University",
    "PUSHS": "Purbanchal University",
    "PUSHS goathgau morang": "Purbanchal University",
    "Purbanchal University School Of Health Science ": "Purbanchal University",
    "Purbanchal University School Of Health Sciences": "Purbanchal University",
    "Purbanchal University School Of Health Sciences ": "Purbanchal University",
    "Purbanchal University School Of Health Sciences , Morang": "Purbanchal University",
    "Purbanchal University School of Health Science ": "Purbanchal University",
    "Purbanchal University School of Health Sciences": "Purbanchal University",
    "Purbanchal University School of Health Sciences ": "Purbanchal University",
    "Purbanchal University School of health and sciences ": "Purbanchal University",
    "Purbanchal University School of health sciences ": "Purbanchal University",
    "Purbanchal University school of Health and Sciences ": "Purbanchal University",
    "Purbanchal University school of health sciences ": "Purbanchal University",
    "Purbanchal university": "Purbanchal University",
    "Purbanchal university ": "Purbanchal University",
    "Purbanchal university school of health and science ": "Purbanchal University",
    "Purbanchal university school of health science": "Purbanchal University",
    "Purbanchal university school of health science ": "Purbanchal University",
    "Purbanchal university school of health sciences": "Purbanchal University",
    "Purbanchal university school of health sciences ": "Purbanchal University",
    "Purbanchal university,Shree college of technology ": "Purbanchal University",

    # MBAHS
    "MBAHS": "Madan Bhandari Academy of Health Sciences",
    "madan bhandari academy of health science": "Madan Bhandari Academy of Health Sciences",
    "madan bhandari academy of health sciences": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of Health Science": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of Health Science ": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of Health Sciences": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of Health Sciences ": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of Health Sciences, Hetauda ": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Academy of health sciences ": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari Acedemy of Health Sciences ": "Madan Bhandari Academy of Health Sciences",
    "Madan Bhandari academy of health sciences ": "Madan Bhandari Academy of Health Sciences",
    "Madan bhandari Academy of health sciences ": "Madan Bhandari Academy of Health Sciences",
    "Madan bhandari academic  of health sciences": "Madan Bhandari Academy of Health Sciences",
    "Madan bhandari academy of health science": "Madan Bhandari Academy of Health Sciences",
    "Madan bhandari academy of health science ": "Madan Bhandari Academy of Health Sciences",

    # PoU (Pokhara University)
    "PU(SMTC/SCoT)": "Pokhara University",
    "Pokhara University": "Pokhara University",
    "Pokhara University ": "Pokhara University",
    "Pokhara university ": "Pokhara University",
    "Pokhara university shas": "Pokhara University",
}

df['Name of University (eg. Purbanchal University)'] = df['Name of University (eg. Purbanchal University)'].replace(university_mapping)

# %%
df['Name of University (eg. Purbanchal University)'].value_counts()
# Out:
# Name of University (eg. Purbanchal University)
# Purbanchal University                        183
# Madan Bhandari Academy of Health Sciences     35
# Tribhuvan University                          24
# Karnali Academy of Health Sciences            23
# Pokhara University                            10
# Name: count, dtype: int64

# %% [markdown]
# # KNOWLEDGE ON DIGITAL HEALTH

# %%
def remove_prefix(text):
    return text.split(". ", 1)[-1]  # Split on ". " and take the second part

# Apply the function to the column
df["How does digital health contribute to epidemic control and surveillance?"] = df["How does digital health contribute to epidemic control and surveillance?"].apply(remove_prefix)

# %%
# 1. Define the comprehensive mapping for all 25 questions.
# A score of 1 is assigned to the correct answer, and 0 to incorrect ones.
score_replace = {
    # Section I: Digital Health Knowledge
    "Which statement best defines the broad field of 'digital health'?": {
        'The application of information and communication technologies (ICT) across the entire spectrum of health and healthcare delivery.': 1,
        'The professional use of social media by doctors to share health tips.': 0,
        'The process of completely replacing all traditional healthcare services with automated technology.': 0,
        'The specific practice of digitizing paper-based patient records into PDF files.': 0
    },
    'Which of the following are all considered key components of the digital health ecosystem?': {
        'Telehealth, mHealth, wearable devices, and Electronic Health Records (EHRs).': 1,
        'Only hospital administration software and billing systems.': 0,
        'Only social media and health-focused television shows.': 0,
        'Traditional medicine practices and printed health journals.': 0
    },
    'How does digital health most significantly support the core principles of public health?': {
        'By applying technological innovations to improve health results for the whole population.': 1,
        'By focusing only on treating individual patients after they get sick.': 0,
        'By replacing the need for public health organizations and community efforts.': 0,
        'By limiting healthcare access to only those with advanced technical skills.': 0
    },
    'How does digital health contribute to epidemic control and surveillance?': {
        'Through real-time data collection, analysis, and reporting': 1,
        'By eliminating the need for vaccines': 0,
        'By replacing all laboratory tests': 0,
        'Through solely manual record-keeping': 0
    },
    'Which factor is often cited as a major barrier to digital health adoption in rural Nepal?': {
        'Limited digital literacy among users and providers': 1,
        'High smartphone ownership': 0,
        'Strong internet infrastructure': 0,
        'Overabundance of healthcare workers': 0
    },
    # Section II: Telehealth
    'What do you understand by telehealth?': {
        'A broad field that uses telecommunications to deliver health care, health education, and health information services, both clinically and non-clinically.': 1,
        'The practice of medicine using telecommunication technology to provide clinical care from a distance, primarily involving real-time video calls between a doctor and patient.': 0,
        'The use of electronic health records (EHRs) and other patient data between different healthcare institutions.': 0,
        'The use of mobile devices for the purpose of personal health and wellness tracking by an individual.': 0
    },
    'Which of the following scenario is the example of telehealth?': {
        'A health worker in a rural health post consulting a specialist in a city hospital via video call.': 1,
        'A doctor accessing a patient\'s digital health record from a different hospital before an in-person appointment.': 0,
        'A public health officer sending an automated SMS reminder to a community about an upcoming vaccination camp.': 0,
        'A medical student watching a pre-recorded surgical procedure online as part of their training.': 0
    },
    'What is a key advantage of implementing telehealth in Nepal’s geographically challenging rural areas?': {
        'Enhancing healthcare access and reducing health disparities for remote and underserved populations.': 1,
        'Increasing the personal convenience for individual patients by eliminating their need to travel for every appointment.': 0,
        'Facilitating the transition from paper-based medical records to more efficient Electronic Health Record (EHR) systems.': 0,
        'Guaranteeing superior health outcomes for all chronic conditions compared to traditional in-person care.': 0
    },
    'Which challenge is particularly significant for sustaining telehealth services in remote, mountainous regions of Nepal?': {
        'Frequent power outages and unreliable electricity supply': 1,
        'Consistently high-speed internet connectivity': 0,
        'Ease of patient transportation': 0,
        'An oversupply of highly qualified telehealth specialists': 0
    },
    'Which of the following is a critical ethical concern in telehealth?': {
        'Patient data privacy and confidentiality': 1,
        'Increasing healthcare jobs': 0,
        'Use of traditional medicine': 0,
        'Video call quality': 0
    },
    # Section III: mHealth
    'What do you understand by mhealth?': {
        'Mobile devices (like smartphones, tablets) and wireless technologies': 1,
        'Hospital-based desktop computer networks and landline phones.': 0,
        'Health education materials like posters and brochures.': 0,
        'Health-related programs broadcasted on national television and radio': 0
    },
    'How can mHealth improve health outcomes?': {
        'Providing timely reminders for appointments and health tips': 1,
        'By replacing all necessary in-person clinical checkups': 0,
        'Reducing the cost of health care services': 0,
        'Eliminating the need for trained midwives or health workers': 0
    },
    'The strategic focus of mHealth is primarily on:': {
        'Using mobile technologies to strengthen health systems and achieve public health goals.': 1,
        'Developing expensive, luxury health apps for a small segment of the population.': 0,
        'Banning the use of personal mobile devices inside all clinic premises.': 0,
        'Creating complex games to make health education more entertaining.': 0
    },
    'Which of the following is a primary application of mHealth in public health surveillance?': {
        'Enabling community health workers to report infectious disease symptoms in real-time using a simple mobile form.': 1,
        'Performing remote surgeries using a smartphone camera.': 0,
        'Replacing laboratory tests for confirming diseases like malaria or dengue.': 0,
        'Dispatching ambulances based on GPS location only.': 0
    },
    'What is the significant challenge of mhealth in context of Nepal?': {
        'The need for content to be available in multiple local languages and be culturally appropriate.': 1,
        'Ensuring the app functions on both Android and iOS platforms.': 0,
        'The fact that most Nepalis do not own a mobile phone.': 0,
        'The high cost of sending a single SMS message.': 0
    },
    # Section IV: Wearable Devices
    'Wearable devices in health are commonly used to monitor ?': {
        'Daily physical activity (step count), heart rate, and sleep patterns.': 1,
        'The exact nutritional content of meals consumed.': 0,
        'ABO blood group type': 0,
        'The presence of specific bacteria or viruses in the body.': 0
    },
    'What is a common limitation associated with the data obtained from consumer wearable devices?': {
        'Dependence on correct usage and compliance by the individual': 1,
        'Consistently high accuracy': 0,
        'The inability to collect data in real-time': 0,
        'They require a doctor\'s prescription to purchase and use.': 0
    },
    'Which wearable device is best for people suffering from non-communicable disease to manage their condition?': {
        'A smartwatch that checks your heart and the oxygen in your blood': 1,
        'Virtual Reality Headsets': 0,
        'Smart Rings that track sleep': 0,
        'Augmented Reality Glasses': 0
    },
    'How do wearable devices help in preventive healthcare?': {
        'Encouraging self-monitoring of physical activity and vital signs': 1,
        'By providing definitive diagnoses for complex diseases': 0,
        'Replacing the need for all routine hospital or clinic visits': 0,
        'Offering guaranteed cures for chronic health conditions': 0
    },
    'In the context of Nepal, the widespread adoption of health-related wearable technology is often hindered by:': {
        'Lack of awareness, affordability, and perceived utility': 1,
        'Income across the population': 0,
        'Universal access to advanced diagnostic facilities': 0,
        'Government subsidies for purchasing devices': 0
    },
    # Section V: Electronic Health Records (EHRs)
    'What do you understand by Electronic Health Record (EHR)?': {
        'A secure, real-time, digital repository of a patient\'s comprehensive health journey': 1,
        'A paper-based folder containing a patient\'s historical charts': 0,
        'A public website where anyone can look up a person\'s medical history.': 0,
        'Standardized insurance claim submission forms': 0
    },
    'What is a key advantage of using EHRs in a healthcare system?': {
        'It improves the coordination and continuity of care, as authorized providers can access a patient\'s history.': 1,
        'It makes patient health information available only to the patient themselves.': 0,
        'It increases the amount of paper that hospitals need to store securely.': 0,
        'It requires patient data to be manually re-entered every time they visit a new clinic.': 0
    },
    'The District Health Information Software 2 (DHIS2) system, used in Nepal, is primarily an example of:': {
        'A national-level health information management system for collecting and analyzing aggregated health data.': 1,
        'A direct-to-patient video consultation app.': 0,
        'A wearable fitness device distributed by the government.': 0,
        'An advanced robotic tool used for performing surgeries.': 0
    },
    'What does ‘interoperability’ mean?': {
        'The ability of different EHR systems from different hospitals or clinics to securely exchange and use health information.': 1,
        'The policy of keeping a patient\'s data isolated within a single hospital\'s system to ensure privacy.': 0,
        'A feature that restricts EHR access to only one specific software company.': 0,
        'The requirement for all healthcare staff to have exceptional computer programming skills.': 0
    },
    'Which factor poses a significant challenge to the successful implementation and maintenance of EHRs, particularly in resource-limited settings like parts of Nepal?': {
        'Limited or unreliable digital infrastructure in rural areas': 1,
        'Exceptionally high digital literacy rates among all healthcare staff': 0,
        'An overabundance of funding specifically allocated for EHR projects': 0,
        'Significant overstaffing in primary healthcare facilities': 0
    }
}


for column, mapping in score_replace.items():
    if column in df.columns:
        # A. Data Cleaning: Strip leading/trailing whitespace and the trailing period
        # This addresses inconsistencies often found in survey data
        df[column] = df[column].astype(str).str.strip().str.rstrip('.')

        # B. Apply the replacement mapping
        # We need to update the mapping keys to match the cleaned strings for the problematic column
        # Specifically, ensure the keys for 'How does digital health...' do not have a period
        cleaned_mapping = {
            k.rstrip('.'): v for k, v in mapping.items()
        }
        df[column] = df[column].replace(cleaned_mapping)

        # C. Convert the column to integer type after replacement
        try:
            df[column] = pd.to_numeric(df[column], errors='raise').astype('Int64')
        except ValueError as e:
            print(f"Failed to convert column '{column}' to integer after replacement. Check for unreplaced values.")
            print(f"Error: {e}")

    else:
        print(f"Warning: Column '{column}' not found in the DataFrame.")
# Out:
# /tmp/ipython-input-238277873.py:174: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[column] = df[column].replace(cleaned_mapping)
# /tmp/ipython-input-238277873.py:174: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[column] = df[column].replace(cleaned_mapping)
# ...

# %%
display(all_question_stats_df)
# Out:
#                                              Question  \
# 0   Which statement best defines the broad field o...
# 1   Which statement best defines the broad field o...
# 2   Which statement best defines the broad field o...
# 3   Which statement best defines the broad field o...
# 4   Which of the following are all considered key ...
# ..                                                ...
# 94                 What does ‘interoperability’ mean?
# 95  Which factor poses a significant challenge to ...
# 96  Which factor poses a significant challenge to ...
# 97  Which factor poses a significant challenge to ...
# 98  Which factor poses a significant challenge to ...
#
#                                                Option  Frequency  Percentage
# 0   The application of information and communicati...        238   86.545455
# 1   The professional use of social media by doctor...         21    7.636364
# 2   The process of completely replacing all tradit...         10    3.636364
# ...

# %%
section_1_questions = [
    "Which statement best defines the broad field of 'digital health'?",
    "Which of the following are all considered key components of the digital health ecosystem?",
    "How does digital health most significantly support the core principles of public health?",
    "How does digital health contribute to epidemic control and surveillance?",
    "Which factor is often cited as a major barrier to digital health adoption in rural Nepal?"
]

df['Digital_Health_knowledge'] = df[section_1_questions].sum(axis=1)
df['Digital_Health_knowledge'].value_counts()
# Out:
# Digital_Health_knowledge
# 5    199
# 4     42
# 3     23
# 0      4
# 1      4
# 2      3
# Name: count, dtype: Int64

# %%
# 1. Define the specific questions for Section II: Telehealth.
section_2_questions = [
    'What do you understand by telehealth?',
    'Which of the following scenario is the example of telehealth?',
    'What is a key advantage of implementing telehealth in Nepal’s geographically challenging rural areas?',
    'Which challenge is particularly significant for sustaining telehealth services in remote, mountainous regions of Nepal?',
    'Which of the following is a critical ethical concern in telehealth?'
]

# 2. Calculate the sum for this section and create the new 'Telehealth_knowledge' column.
df['Telehealth_knowledge'] = df[section_2_questions].sum(axis=1)

# 3. Display the value counts for the new score column.
df['Telehealth_knowledge'].value_counts()
# Out:
# Telehealth_knowledge
# 4    94
# 3    80
# 2    43
# 5    35
# 1    17
# 0     6
# Name: count, dtype: Int64

# %%
section_3_questions = [
    'What do you understand by mhealth?',
    'How can mHealth improve health outcomes?',
    'The strategic focus of mHealth is primarily on:',
    'Which of the following is a primary application of mHealth in public health surveillance?',
    'What is the significant challenge of mhealth in context of Nepal?'
]

df['mhealth_knowledge'] = df[section_3_questions].sum(axis=1)

df['mhealth_knowledge'].value_counts()
# Out:
# mhealth_knowledge
# 4    113
# 5     87
# 3     48
# 2     16
# 1      9
# 0      2
# Name: count, dtype: Int64

# %%
section_4_questions = [
  'Wearable devices in health are commonly used to monitor ?',
  'What is a common limitation associated with the data obtained from consumer wearable devices?',
  'Which wearable device is best for people suffering from non-communicable disease to manage their condition?',
  'How do wearable devices help in preventive healthcare?',
  'In the context of Nepal, the widespread adoption of health-related wearable technology is often hindered by:'
]

df['wearable_device_knowledge'] = df[section_4_questions].sum(axis=1)

df['wearable_device_knowledge'].value_counts()
# Out:
# wearable_device_knowledge
# 5    172
# 4     57
# 3     22
# 2     11
# 1      9
# 0      4
# Name: count, dtype: Int64

# %%
section_5_questions = [
  'What do you understand by Electronic Health Record (EHR)?',
  'What is a key advantage of using EHRs in a healthcare system?',
  'The District Health Information Software 2 (DHIS2) system, used in Nepal, is primarily an example of:',
  'What does ‘interoperability’ mean?',
  'Which factor poses a significant challenge to the successful implementation and maintenance of EHRs, particularly in resource-limited settings like parts of Nepal?'
]

df['EHR_knowledge'] = df[section_5_questions].sum(axis=1)

df['EHR_knowledge'].value_counts()
# Out:
# EHR_knowledge
# 5    124
# 4     79
# 3     34
# 1     16
# 2     16
# 0      6
# Name: count, dtype: Int64

# %%
cols = ['Digital_Health_knowledge', 'Telehealth_knowledge',
        'mhealth_knowledge', 'wearable_device_knowledge',
        'EHR_knowledge']

# Calculate mean percentage for each column
mean_percentage = (df[cols].mean() / df[cols].max()) * 100

# Function to classify knowledge level
def classify(percentage):
    if percentage > 80:
        return 'High knowledge'
    elif percentage >= 50:
        return 'Moderate knowledge'
    else:
        return 'Low knowledge'

# Apply classification to each column's mean percentage
knowledge_classification = mean_percentage.apply(classify)

# Combine results into one DataFrame
result = pd.DataFrame({
    'Mean_Percentage': mean_percentage,
    'Knowledge_Level': knowledge_classification
})

display(result)
# Out:
#                            Mean_Percentage     Knowledge_Level
# Digital_Health_knowledge         90.327273      High knowledge
# Telehealth_knowledge             65.018182  Moderate knowledge
# mhealth_knowledge                77.963636  Moderate knowledge
# wearable_device_knowledge        86.181818      High knowledge
# EHR_knowledge                    78.981818  Moderate knowledge

# %%
cols = ['Digital_Health_knowledge', 'Telehealth_knowledge',
        'mhealth_knowledge', 'wearable_device_knowledge',
        'EHR_knowledge']

correlation_matrix = df[cols].corr()

display("Correlation Matrix of Knowledge Scores:")
display(correlation_matrix)
# Out:
# 'Correlation Matrix of Knowledge Scores:'
#                            Digital_Health_knowledge  Telehealth_knowledge  \
# Digital_Health_knowledge                   1.000000              0.425991
# Telehealth_knowledge                       0.425991              1.000000
# mhealth_knowledge                          0.512393              0.416366
# wearable_device_knowledge                  0.479135              0.370391
# EHR_knowledge                              0.522626              0.394450
#
#                            mhealth_knowledge  wearable_device_knowledge  \
# Digital_Health_knowledge            0.512393                   0.479135
# Telehealth_knowledge                0.416366                   0.370391
# mhealth_knowledge                   1.000000                   0.528941
# wearable_device_knowledge           0.528941                   1.000000
# EHR_knowledge                       0.589394                   0.656541
#
#                            EHR_knowledge
# ...

# %%
df['Total_knowledge'] = df[['Digital_Health_knowledge','Telehealth_knowledge','mhealth_knowledge','wearable_device_knowledge','EHR_knowledge']].sum(axis=1)

# %%
df['Knowledge_Percentage'] = (df['Total_knowledge'] / 25) * 100

# %%
def classify_knowledge(percentage):
    """
    Classifies a percentage score into Low, Moderate, or High knowledge.
    """
    if percentage > 80:
        return 'High knowledge'
    elif percentage >= 50:
        return 'Moderate knowledge'
    else:
        return 'Low knowledge'

# Apply the function to the existing 'Knowledge_Percentage' column
df['Knowledge_Classification'] = df['Knowledge_Percentage'].apply(classify_knowledge)

# %%
knowledge_counts = df['Knowledge_Classification'].value_counts()
knowledge_percentages = df['Knowledge_Classification'].value_counts(normalize=True) * 100

# Combine counts and percentages into a single DataFrame for display
knowledge_summary = pd.DataFrame({
    'Count': knowledge_counts,
    'Percentage': knowledge_percentages
})

display(knowledge_summary)

mean_score = df['Knowledge_Percentage'].mean()
display(f'The mean knowledge score of digital health is {mean_score:.2f}%')
# Out:
#                           Count  Percentage
# Knowledge_Classification
# High knowledge              153   55.636364
# Moderate knowledge           98   35.636364
# Low knowledge                24    8.727273
# 'The mean knowledge score of digital health is 79.69%'

# %% [markdown]
# # PRIOR EXPOSURE

# %%
display(df['Inclusion of digital health in your curriculum:'].value_counts())
display(df['Formal Training in digital health'].value_counts())
display(df['Online Courses on Digital Health:'].value_counts())
# Out:
# Inclusion of digital health in your curriculum:
# Partially included (mentioned in course)     136
# Not Included                                 118
# Fully included (dedicated  course/module)     21
# Name: count, dtype: int64
# Formal Training in digital health
# No formal training                      227
# Yes (Participated but not certified)     40
# Yes (certified training)                  8
# Name: count, dtype: int64
# Online Courses on Digital Health:
# No Any Courses          252
# Completed 1 course       13
# Completed ≥2 courses     10
# Name: count, dtype: int64

# %%
#MAPPING THE VALUE

mapping = {
    'Not Included': 0,
    'Partially included (mentioned in course)': 1,
    'Fully included (dedicated  course/module)': 2
}

df['Prior_exposure_curriculum'] = df['Inclusion of digital health in your curriculum:'].map(mapping)

mapping_training = {
    'No formal training': 0,
    'Yes (Participated but not certified)': 1,
    'Yes (certified training)': 2
}

df['Prior_Exposure_Training'] = df['Formal Training in digital health'].map(mapping_training)

mapping_training = {
    'No Any Courses': 0,
    'Completed 1 course': 1,
    'Completed ≥2 courses': 2
}

df['Prior_Exposure_online_course'] = df['Online Courses on Digital Health:'].map(mapping_training)

# %%
# Sum the mapped prior exposure columns
df['Total_Prior_Exposure'] = df['Prior_exposure_curriculum'] + df['Prior_Exposure_Training'] + df['Prior_Exposure_online_course']

# Define the exposure categories based on the sum
def categorize_exposure(total_exposure):
    if total_exposure <= 2:
        return 'Low Exposure'
    elif 3 <= total_exposure <= 4:
        return 'Moderate Exposure'
    elif total_exposure >= 5:
        return 'High Exposure'
    else:
        return 'Unknown' # Handle any unexpected values

# Apply the categorization function to create the new column
df['Prior_Exposure_Category'] = df['Total_Prior_Exposure'].apply(categorize_exposure)



exposure_summary = pd.DataFrame({
    'Count':df['Prior_Exposure_Category'].value_counts() ,
    'Percentage': (df['Prior_Exposure_Category'].value_counts() / len(df)) * 100})

display(exposure_summary)
# Out:
#                          Count  Percentage
# Prior_Exposure_Category
# Low Exposure               251   91.272727
# Moderate Exposure           16    5.818182
# High Exposure                8    2.909091

# %% [markdown]
# # ASSOCIATION

# %% [markdown]
# ## Association between Socio-Demographic and Knowledge Score

# %%
df.columns
# Out:
# Index(['Name:', 'Age', 'Gender',
#        'Name of University (eg. Purbanchal University)', 'Parental Education',
#        'Place of residence (Permanent)', 'Family Monthly Income',
#        'Education Background', 'Academic Year',
#        'Inclusion of digital health in your curriculum:',
#        'Formal Training in digital health',
#        'Online Courses on Digital Health:',
#        'Which statement best defines the broad field of 'digital health'?',
#        'Which of the following are all considered key components of the digital health ecosystem?',
#        'How does digital health most significantly support the core principles of public health?',
#        'How does digital health contribute to epidemic control and surveillance?',
#        'Which factor is often cited as a major barrier to digital health adoption in rural Nepal?',
#        'What do you understand by telehealth?',
#        'Which of the following scenario is the example of telehealth?',
# ...

# %%
from scipy.stats import ttest_1samp

# Perform one-sample t-test on 'Total_knowledge' against a benchmark of 50%
# Since 'Total_knowledge' is a sum out of 25 questions, the benchmark is 25 * 0.50 = 12.5
benchmark = 12.5
t_statistic, p_value = ttest_1samp(df['Total_knowledge'], benchmark)

display(f"One-Sample T-test against a benchmark of {benchmark} (50%):")
display(f"T-statistic: {t_statistic}")
display(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    display(f"Result: The mean total digital health knowledge score is significantly different from the benchmark of {benchmark} (p < {alpha}).")
else:
    display(f"Result: The mean total digital health knowledge score is not significantly different from the benchmark of {benchmark} (p >= {alpha}).")
# Out:
# 'One-Sample T-test against a benchmark of 12.5 (50%):'
# 'T-statistic: 28.249766611339922'
# 'P-value: 3.789893546968109e-83'
# 'Result: The mean total digital health knowledge score is significantly different from the benchmark of 12.5 (p < 0.05).'

# %%
from scipy import stats

knowledge_cols = [
    'Digital_Health_knowledge',
    'Telehealth_knowledge',
    'mhealth_knowledge',
    'wearable_device_knowledge',
    'EHR_knowledge'
]

for col in knowledge_cols:
    display(f"ANOVA test for {col} across Knowledge Classification:")

    # Create a list of arrays, one for each knowledge classification category
    groups = [df[col][df['Knowledge_Classification'] == cls].dropna() for cls in df['Knowledge_Classification'].unique()]

    # Perform the ANOVA test
    fvalue, pvalue = stats.f_oneway(*groups)

    display(f"F-statistic: {fvalue}")
    display(f"P-value: {pvalue}")

    alpha = 0.05
    if pvalue < alpha:
        display(f"Result: There is a statistically significant difference in mean {col} across digital health domain Knowledge (p < {alpha}).")
    else:
        display(f"Result: There is no statistically significant difference in mean {col} across digital health domain Knowledge (p >= {alpha}).")
    display("-" * 50)
# Out:
# 'ANOVA test for Digital_Health_knowledge across Knowledge Classification:'
# 'F-statistic: 117.6040423178844'
# 'P-value: 1.5705515211632245e-37'
# 'Result: There is a statistically significant difference in mean Digital_Health_knowledge across digital health domain Knowledge (p < 0.05).'
# '--------------------------------------------------'
# 'ANOVA test for Telehealth_knowledge across Knowledge Classification:'
# 'F-statistic: 89.10332085184241'
# 'P-value: 1.727240709991705e-30'
# 'Result: There is a statistically significant difference in mean Telehealth_knowledge across digital health domain Knowledge (p < 0.05).'
# '--------------------------------------------------'
# 'ANOVA test for mhealth_knowledge across Knowledge Classification:'
# 'F-statistic: 146.06647824394705'
# 'P-value: 8.1939022770728e-44'
# 'Result: There is a statistically significant difference in mean mhealth_knowledge across digital health domain Knowledge (p < 0.05).'
# ...

# %%
from scipy.stats import chi2_contingency

demographic_columns = [
    'Age_Category',
    'Gender',
    'Name of University (eg. Purbanchal University)',
    'Parental Education',
    'Place of residence (Permanent)',
    'Family Monthly Income',
    'Education Background',
    'Academic Year'
]

for demo_col in demographic_columns:
    display(f"Chi-square test between Knowledge Classification and {demo_col}:")
    contingency_table = pd.crosstab(df['Knowledge_Classification'], df[demo_col])
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    display(f"Chi-square statistic: {chi2}")
    display(f"P-value: {p}")
    display(f"Degrees of freedom: {dof}")
    # display("Expected frequencies:")
    # display(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))

    alpha = 0.05
    if p < alpha:
        display(f"Result: There is a statistically significant association between Knowledge Classification and {demo_col} (p < {alpha}).")
    else:
        display(f"Result: There is no statistically significant association between Knowledge Classification and {demo_col} (p >= {alpha}).")
    display("-" * 50)
# Out:
# 'Chi-square test between Knowledge Classification and Age_Category:'
# 'Chi-square statistic: 20.587122470402704'
# 'P-value: 0.0021756385518233163'
# 'Degrees of freedom: 6'
# 'Result: There is a statistically significant association between Knowledge Classification and Age_Category (p < 0.05).'
# '--------------------------------------------------'
# 'Chi-square test between Knowledge Classification and Gender:'
# 'Chi-square statistic: 5.2064307823715845'
# 'P-value: 0.07403514314204766'
# 'Degrees of freedom: 2'
# 'Result: There is no statistically significant association between Knowledge Classification and Gender (p >= 0.05).'
# '--------------------------------------------------'
# 'Chi-square test between Knowledge Classification and Name of University (eg. Purbanchal University):'
# 'Chi-square statistic: 11.07138928930531'
# 'P-value: 0.19768690482019602'
# 'Degrees of freedom: 8'
# ...

# %%
from scipy.stats import ttest_1samp

# Perform one-sample t-test on 'Total_knowledge' against a benchmark of higher than 50%
# Let's set the benchmark to 60% (15 out of 25)
benchmark = 15
t_statistic, p_value = ttest_1samp(df['Total_knowledge'], benchmark)

display(f"One-Sample T-test against a benchmark of {benchmark} (60%):")
display(f"T-statistic: {t_statistic}")
display(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    display(f"Result: The mean total digital health knowledge score is significantly different from the benchmark of {benchmark} (p < {alpha}).")
else:
    display(f"Result: The mean total digital health knowledge score is not significantly different from the benchmark of {benchmark} (p >= {alpha}).")
# Out:
# 'One-Sample T-test against a benchmark of 15 (60%):'
# 'T-statistic: 18.736313490940116'
# 'P-value: 5.473686823624535e-51'
# 'Result: The mean total digital health knowledge score is significantly different from the benchmark of 15 (p < 0.05).'

# %% [markdown]
# ## Association between Prior Exposure and Knowledge Score

# %%
from scipy.stats import chi2_contingency

display("Chi-square test between Prior Exposure Category and Knowledge Classification:")
contingency_table = pd.crosstab(df['Prior_Exposure_Category'], df['Knowledge_Classification'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

display(f"Chi-square statistic: {chi2}")
display(f"P-value: {p}")
display(f"Degrees of freedom: {dof}")

alpha = 0.05
if p < alpha:
    display(f"Result: There is a statistically significant association between Prior Exposure Category and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Prior Exposure Category and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Chi-square test between Prior Exposure Category and Knowledge Classification:'
# 'Chi-square statistic: 6.535750816760967'
# 'P-value: 0.16255168481133392'
# 'Degrees of freedom: 4'
# 'Result: There is no statistically significant association between Prior Exposure Category and Knowledge Classification (p >= 0.05).'

# %%
from scipy.stats import ttest_ind

# Separate the total knowledge scores by gender
male_knowledge = df['Total_knowledge'][df['Gender'] == 'Male']
female_knowledge = df['Total_knowledge'][df['Gender'] == 'Female']

# Perform the independent samples t-test
t_statistic, p_value = ttest_ind(male_knowledge, female_knowledge)

display("Independent Samples T-test for Total Knowledge by Gender:")
display(f"T-statistic: {t_statistic}")
display(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    display(f"Result: There is a statistically significant difference in mean total digital health knowledge scores between male and female students (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant difference in mean total digital health knowledge scores between male and female students (p >= {alpha}).")
# Out:
# 'Independent Samples T-test for Total Knowledge by Gender:'
# 'T-statistic: -2.742554566162953'
# 'P-value: 0.006499558278756751'
# 'Result: There is a statistically significant difference in mean total digital health knowledge scores between male and female students (p < 0.05).'

# %%
from scipy.stats import ttest_ind

# Separate the total knowledge scores by education background
science_knowledge = df['Total_knowledge'][df['Education Background'] == '+2 science']
diploma_knowledge = df['Total_knowledge'][df['Education Background'] == 'Diploma in health sciences (HA, Pharmacy or any other from CTEVT)']

# Perform the independent samples t-test
t_statistic, p_value = ttest_ind(science_knowledge, diploma_knowledge)

display("Independent Samples T-test for Total Knowledge by Education Background:")
display(f"T-statistic: {t_statistic}")
display(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    display(f"Result: There is a statistically significant difference in mean total digital health knowledge scores between students with +2 Science and Diploma in Health Sciences backgrounds (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant difference in mean total digital health knowledge scores between students with +2 Science and Diploma in Health Sciences backgrounds (p >= {alpha}).")
# Out:
# 'Independent Samples T-test for Total Knowledge by Education Background:'
# 'T-statistic: -1.9883636080133589'
# 'P-value: 0.04776993521022441'
# 'Result: There is a statistically significant difference in mean total digital health knowledge scores between students with +2 Science and Diploma in Health Sciences backgrounds (p < 0.05).'

# %%
from scipy import stats

# ANOVA for Academic Year
display("ANOVA test for Total Knowledge by Academic Year:")
academic_year_groups = [df['Total_knowledge'][df['Academic Year'] == year].dropna() for year in df['Academic Year'].unique()]
fvalue_academic, pvalue_academic = stats.f_oneway(*academic_year_groups)
display(f"F-statistic: {fvalue_academic}")
display(f"P-value: {pvalue_academic}")
alpha = 0.05
if pvalue_academic < alpha:
    display(f"Result: There is a statistically significant difference in mean total digital health knowledge scores across different academic years (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant difference in mean total digital health knowledge scores across different academic years (p >= {alpha}).")
display("-" * 50)

# ANOVA for Family Monthly Income
display("ANOVA test for Total Knowledge by Family Monthly Income:")
income_groups = [df['Total_knowledge'][df['Family Monthly Income'] == income].dropna() for income in df['Family Monthly Income'].unique()]
fvalue_income, pvalue_income = stats.f_oneway(*income_groups)
display(f"F-statistic: {fvalue_income}")
display(f"P-value: {pvalue_income}")
alpha = 0.05
if pvalue_income < alpha:
    display(f"Result: There is a statistically significant difference in mean total digital health knowledge scores across different family monthly income brackets (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant difference in mean total digital health knowledge scores across different family monthly income brackets (p >= {alpha}).")
display("-" * 50)

# ANOVA for Age Category
display("ANOVA test for Total Knowledge by Age Category:")
age_category_groups = [df['Total_knowledge'][df['Age_Category'] == category].dropna() for category in df['Age_Category'].unique()]
fvalue_age, pvalue_age = stats.f_oneway(*age_category_groups)
display(f"F-statistic: {fvalue_age}")
display(f"P-value: {pvalue_age}")
alpha = 0.05
if pvalue_age < alpha:
    display(f"Result: There is a statistically significant difference in mean total digital health knowledge scores across the different age categories (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant difference in mean total digital health knowledge scores across the different age categories (p >= {alpha}).")
# Out:
# 'ANOVA test for Total Knowledge by Academic Year:'
# 'F-statistic: 2.0676955979728313'
# 'P-value: 0.10479070255788775'
# 'Result: There is no statistically significant difference in mean total digital health knowledge scores across different academic years (p >= 0.05).'
# '--------------------------------------------------'
# 'ANOVA test for Total Knowledge by Family Monthly Income:'
# 'F-statistic: 7.7224624209924295'
# 'P-value: 5.729117593049103e-05'
# 'Result: There is a statistically significant difference in mean total digital health knowledge scores across different family monthly income brackets (p < 0.05).'
# '--------------------------------------------------'
# 'ANOVA test for Total Knowledge by Age Category:'
# 'F-statistic: 2.9694329638107044'
# 'P-value: 0.032347154213350396'
# 'Result: There is a statistically significant difference in mean total digital health knowledge scores across the different age categories (p < 0.05).'

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create a contingency table for 'Age_Category' and 'Knowledge_Classification'
contingency_table_observed = pd.crosstab(df['Age_Category'], df['Knowledge_Classification'])
display("Observed Contingency Table (Age Category vs. Knowledge Classification):")
display(contingency_table_observed)

# 2. Calculate the observed Chi-square statistic
chi2_observed, p_observed, dof_observed, expected_observed = chi2_contingency(contingency_table_observed)

display(f"\nObserved Chi-square statistic: {chi2_observed:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics = []

# 4. Set the number of permutations
n_permutations = 5000  # Increased permutations for better approximation

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled = df.copy()
    df_shuffled['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted = pd.crosstab(
        df_shuffled['Age_Category'],
        df_shuffled['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted, _, _, _ = chi2_contingency(contingency_table_permuted)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics.append(chi2_permuted)

# 6. Calculate the p-value from the permutation test
p_value_permutation = np.sum(np.array(permuted_chi2_statistics) >= chi2_observed) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation:.4f}")

alpha = 0.05
if p_value_permutation < alpha:
    display(f"Result: There is a statistically significant association between Age Category and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Age Category and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Age Category vs. Knowledge Classification):'
# Knowledge_Classification  High knowledge  Low knowledge  Moderate knowledge
# Age_Category
# 15-19                                  2              3                  11
# 20-24                                115             12                  67
# 25-29                                 29              8                  12
# 30-34                                  7              1                   8
# '\nObserved Chi-square statistic: 20.59'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.0042'
# 'Result: There is a statistically significant association between Age Category and Knowledge Classification (p < 0.05).'

# %% [markdown]
# # Task
# Perform a permutation test to assess the association between 'Name of University (eg. Purbanchal University)' and 'Knowledge_Classification', approximating the Fisher-Freeman-Halton exact test. This will involve creating an observed contingency table, calculating the observed Chi-square statistic, then running 5000 permutations by shuffling the 'Knowledge_Classification' column and recalculating the Chi-square for each permuted table to derive a p-value.

# %% [markdown]
# ## Permutation Test for University Name
#
# ### Subtask:
# Perform a permutation test to assess the association between 'Name of University (eg. Purbanchal University)' and 'Knowledge_Classification', approximating the Fisher-Freeman-Halton exact test.

# %% [markdown]
# **Reasoning**:
# The subtask requires performing a permutation test between 'Name of University (eg. Purbanchal University)' and 'Knowledge_Classification'. This involves creating an observed contingency table, calculating the observed Chi-square statistic, running a permutation loop to generate permuted Chi-square statistics, and then calculating and displaying the permutation p-value. I will consolidate these steps into a single code block to ensure efficient execution and a clear, sequential flow of the permutation test.

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create a contingency table for 'Name of University (eg. Purbanchal University)' and 'Knowledge_Classification'
contingency_table_observed_uni = pd.crosstab(df['Name of University (eg. Purbanchal University)'], df['Knowledge_Classification'])
display("Observed Contingency Table (University vs. Knowledge Classification):")
display(contingency_table_observed_uni)

# 2. Calculate the observed Chi-square statistic
chi2_observed_uni, p_observed_uni, dof_observed_uni, expected_observed_uni = chi2_contingency(contingency_table_observed_uni)

display(f"\nObserved Chi-square statistic: {chi2_observed_uni:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_uni = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_uni = df.copy()
    df_shuffled_uni['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_uni['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_uni = pd.crosstab(
        df_shuffled_uni['Name of University (eg. Purbanchal University)'],
        df_shuffled_uni['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_uni, _, _, _ = chi2_contingency(contingency_table_permuted_uni)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_uni.append(chi2_permuted_uni)

# 6. Calculate the p-value from the permutation test
p_value_permutation_uni = np.sum(np.array(permuted_chi2_statistics_uni) >= chi2_observed_uni) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_uni:.4f}")

alpha = 0.05
if p_value_permutation_uni < alpha:
    display(f"Result: There is a statistically significant association between University Name and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between University Name and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (University vs. Knowledge Classification):'
# Knowledge_Classification                        High knowledge  Low knowledge  \
# Name of University (eg. Purbanchal University)
# Karnali Academy of Health Sciences                          10              3
# Madan Bhandari Academy of Health Sciences                   25              0
# Pokhara University                                           4              0
# Purbanchal University                                      103             18
# Tribhuvan University                                        11              3
#
# Knowledge_Classification                        Moderate knowledge
# Name of University (eg. Purbanchal University)
# Karnali Academy of Health Sciences                              10
# Madan Bhandari Academy of Health Sciences                       10
# Pokhara University                                               6
# ...

# %% [markdown]
# ## Permutation Test for Family Monthly Income
#
# ### Subtask:
# Perform a permutation test to assess the association between 'Family Monthly Income' and 'Knowledge_Classification', approximating the Fisher-Freeman-Halton exact test. This involves creating an observed contingency table, calculating the observed Chi-square statistic, then running 5000 permutations by shuffling the 'Knowledge_Classification' column and recalculating the Chi-square for each permuted table to derive a p-value.

# %% [markdown]
# **Reasoning**:
# The subtask requires performing a permutation test to assess the association between 'Family Monthly Income' and 'Knowledge_Classification'. This involves creating an observed contingency table, calculating the observed Chi-square statistic, running a permutation loop to generate permuted Chi-square statistics, and then calculating and displaying the permutation p-value, followed by a significance comparison. I will consolidate these steps into a single code block to ensure efficient execution and a clear, sequential flow of the permutation test.

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create an observed contingency table for 'Family Monthly Income' and 'Knowledge_Classification'
contingency_table_observed_income = pd.crosstab(df['Family Monthly Income'], df['Knowledge_Classification'])
display("Observed Contingency Table (Family Monthly Income vs. Knowledge Classification):")
display(contingency_table_observed_income)

# 2. Calculate the observed Chi-square statistic
chi2_observed_income, p_observed_income, dof_observed_income, expected_observed_income = chi2_contingency(contingency_table_observed_income)

display(f"\nObserved Chi-square statistic: {chi2_observed_income:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_income = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_income = df.copy()
    df_shuffled_income['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_income['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_income = pd.crosstab(
        df_shuffled_income['Family Monthly Income'],
        df_shuffled_income['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_income, _, _, _ = chi2_contingency(contingency_table_permuted_income)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_income.append(chi2_permuted_income)

# 6. Calculate the p-value from the permutation test
p_value_permutation_income = np.sum(np.array(permuted_chi2_statistics_income) >= chi2_observed_income) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_income:.4f}")

alpha = 0.05
if p_value_permutation_income < alpha:
    display(f"Result: There is a statistically significant association between Family Monthly Income and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Family Monthly Income and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Family Monthly Income vs. Knowledge Classification):'
# Knowledge_Classification  High knowledge  Low knowledge  Moderate knowledge
# Family Monthly Income
# 10,000 - 19,999                       14              0                   9
# 20,000 - 29,999                       22              9                  17
# 30,000+                              113             10                  69
# < 9,999                                4              5                   3
# '\nObserved Chi-square statistic: 28.01'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.0002'
# 'Result: There is a statistically significant association between Family Monthly Income and Knowledge Classification (p < 0.05).'

# %% [markdown]
# ## Permutation Test for Prior Exposure Category
#
# ### Subtask:
# Perform a permutation test to assess the association between 'Prior_Exposure_Category' and 'Knowledge_Classification', approximating the Fisher-Freeman-Halton exact test. This involves creating an observed contingency table, calculating the observed Chi-square statistic, then running 5000 permutations by shuffling the 'Knowledge_Classification' column and recalculating the Chi-square for each permuted table to derive a p-value.

# %% [markdown]
# **Reasoning**:
# The subtask requires performing a permutation test to assess the association between 'Prior_Exposure_Category' and 'Knowledge_Classification'. This involves creating an observed contingency table, calculating the observed Chi-square statistic, running a permutation loop to generate permuted Chi-square statistics, and then calculating and displaying the permutation p-value, followed by a significance comparison. I will consolidate these steps into a single code block to ensure efficient execution and a clear, sequential flow of the permutation test.

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create an observed contingency table for 'Prior_Exposure_Category' and 'Knowledge_Classification'
contingency_table_observed_exposure = pd.crosstab(df['Prior_Exposure_Category'], df['Knowledge_Classification'])
display("Observed Contingency Table (Prior Exposure Category vs. Knowledge Classification):")
display(contingency_table_observed_exposure)

# 2. Calculate the observed Chi-square statistic
chi2_observed_exposure, p_observed_exposure, dof_observed_exposure, expected_observed_exposure = chi2_contingency(contingency_table_observed_exposure)

display(f"\nObserved Chi-square statistic: {chi2_observed_exposure:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_exposure = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_exposure = df.copy()
    df_shuffled_exposure['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_exposure['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_exposure = pd.crosstab(
        df_shuffled_exposure['Prior_Exposure_Category'],
        df_shuffled_exposure['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_exposure, _, _, _ = chi2_contingency(contingency_table_permuted_exposure)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_exposure.append(chi2_permuted_exposure)

# 6. Calculate the p-value from the permutation test
p_value_permutation_exposure = np.sum(np.array(permuted_chi2_statistics_exposure) >= chi2_observed_exposure) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_exposure:.4f}")

alpha = 0.05
if p_value_permutation_exposure < alpha:
    display(f"Result: There is a statistically significant association between Prior Exposure Category and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Prior Exposure Category and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Prior Exposure Category vs. Knowledge Classification):'
# Knowledge_Classification  High knowledge  Low knowledge  Moderate knowledge
# Prior_Exposure_Category
# High Exposure                          3              2                   3
# Low Exposure                         144             19                  88
# Moderate Exposure                      6              3                   7
# '\nObserved Chi-square statistic: 6.54'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.1606'
# 'Result: There is no statistically significant association between Prior Exposure Category and Knowledge Classification (p >= 0.05).'

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create an observed contingency table for 'Place of residence (Permanent)' and 'Knowledge_Classification'
contingency_table_observed_residence = pd.crosstab(df['Place of residence (Permanent)'], df['Knowledge_Classification'])
display("Observed Contingency Table (Place of residence (Permanent) vs. Knowledge Classification):")
display(contingency_table_observed_residence)

# 2. Calculate the observed Chi-square statistic
chi2_observed_residence, p_observed_residence, dof_observed_residence, expected_observed_residence = chi2_contingency(contingency_table_observed_residence)

display(f"\nObserved Chi-square statistic: {chi2_observed_residence:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_residence = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_residence = df.copy()
    df_shuffled_residence['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_residence['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_residence = pd.crosstab(
        df_shuffled_residence['Place of residence (Permanent)'],
        df_shuffled_residence['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_residence, _, _, _ = chi2_contingency(contingency_table_permuted_residence)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_residence.append(chi2_permuted_residence)

# 6. Calculate the p-value from the permutation test
p_value_permutation_residence = np.sum(np.array(permuted_chi2_statistics_residence) >= chi2_observed_residence) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_residence:.4f}")

alpha = 0.05
if p_value_permutation_residence < alpha:
    display(f"Result: There is a statistically significant association between Place of residence (Permanent) and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Place of residence (Permanent) and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Place of residence (Permanent) vs. Knowledge Classification):'
# Knowledge_Classification        High knowledge  Low knowledge  \
# Place of residence (Permanent)
# Metropolitan city                           14              1
# Municipality                                84             14
# Rural Municipality                          40              5
# Sub-Metropolitan city                       15              4
#
# Knowledge_Classification        Moderate knowledge
# Place of residence (Permanent)
# Metropolitan city                               14
# Municipality                                    53
# Rural Municipality                              20
# Sub-Metropolitan city                           11
# '\nObserved Chi-square statistic: 4.40'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.6422'
# ...

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create an observed contingency table for 'Education Background' and 'Knowledge_Classification'
contingency_table_observed_education = pd.crosstab(df['Education Background'], df['Knowledge_Classification'])
display("Observed Contingency Table (Education Background vs. Knowledge Classification):")
display(contingency_table_observed_education)

# 2. Calculate the observed Chi-square statistic
chi2_observed_education, p_observed_education, dof_observed_education, expected_observed_education = chi2_contingency(contingency_table_observed_education)

display(f"\nObserved Chi-square statistic: {chi2_observed_education:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_education = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_education = df.copy()
    df_shuffled_education['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_education['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_education = pd.crosstab(
        df_shuffled_education['Education Background'],
        df_shuffled_education['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_education, _, _, _ = chi2_contingency(contingency_table_permuted_education)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_education.append(chi2_permuted_education)

# 6. Calculate the p-value from the permutation test
p_value_permutation_education = np.sum(np.array(permuted_chi2_statistics_education) >= chi2_observed_education) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_education:.4f}")

alpha = 0.05
if p_value_permutation_education < alpha:
    display(f"Result: There is a statistically significant association between Education Background and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Education Background and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Education Background vs. Knowledge Classification):'
# Knowledge_Classification                            High knowledge  \
# Education Background
# +2 science                                                     111
# Diploma in health sciences (HA, Pharmacy or any...              42
#
# Knowledge_Classification                            Low knowledge  \
# Education Background
# +2 science                                                     21
# Diploma in health sciences (HA, Pharmacy or any...              3
#
# Knowledge_Classification                            Moderate knowledge
# Education Background
# +2 science                                                          77
# Diploma in health sciences (HA, Pharmacy or any...                  21
# '\nObserved Chi-square statistic: 3.09'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.2144'
# ...

# %% [markdown]
# ## Permutation Test for Academic Year
#
# ### Subtask:
# Perform a permutation test to assess the association between 'Academic Year' and 'Knowledge_Classification', approximating the Fisher-Freeman-Halton exact test. This involves creating an observed contingency table, calculating the observed Chi-square statistic, then running 5000 permutations by shuffling the 'Knowledge_Classification' column and recalculating the Chi-square for each permuted table to derive a p-value.

# %% [markdown]
# **Reasoning**:
# The subtask requires performing a permutation test to assess the association between 'Academic Year' and 'Knowledge_Classification'. This involves creating an observed contingency table, calculating the observed Chi-square statistic, running a permutation loop to generate permuted Chi-square statistics, and then calculating and displaying the permutation p-value, followed by a significance comparison. I will consolidate these steps into a single code block to ensure efficient execution and a clear, sequential flow of the permutation test.

# %%
from scipy.stats import chi2_contingency
import numpy as np

# 1. Create an observed contingency table for 'Academic Year' and 'Knowledge_Classification'
contingency_table_observed_academic_year = pd.crosstab(df['Academic Year'], df['Knowledge_Classification'])
display("Observed Contingency Table (Academic Year vs. Knowledge Classification):")
display(contingency_table_observed_academic_year)

# 2. Calculate the observed Chi-square statistic
chi2_observed_academic_year, p_observed_academic_year, dof_observed_academic_year, expected_observed_academic_year = chi2_contingency(contingency_table_observed_academic_year)

display(f"\nObserved Chi-square statistic: {chi2_observed_academic_year:.2f}")

# 3. Initialize list for permuted Chi-square statistics
permuted_chi2_statistics_academic_year = []

# 4. Set the number of permutations
n_permutations = 5000

# 5. Loop for permutations
for _ in range(n_permutations):
    # a. Randomly shuffle 'Knowledge_Classification'
    df_shuffled_academic_year = df.copy()
    df_shuffled_academic_year['Knowledge_Classification_permuted'] = np.random.permutation(df_shuffled_academic_year['Knowledge_Classification'])

    # b. Create a new contingency table with permuted data
    contingency_table_permuted_academic_year = pd.crosstab(
        df_shuffled_academic_year['Academic Year'],
        df_shuffled_academic_year['Knowledge_Classification_permuted']
    )

    # c. Calculate the Chi-square statistic for the permuted table
    chi2_permuted_academic_year, _, _, _ = chi2_contingency(contingency_table_permuted_academic_year)

    # d. Append the calculated Chi-square statistic to the list
    permuted_chi2_statistics_academic_year.append(chi2_permuted_academic_year)

# 6. Calculate the p-value from the permutation test
p_value_permutation_academic_year = np.sum(np.array(permuted_chi2_statistics_academic_year) >= chi2_observed_academic_year) / n_permutations

display(f"Permutation Test P-value (approximating Fisher-Freeman-Halton): {p_value_permutation_academic_year:.4f}")

alpha = 0.05
if p_value_permutation_academic_year < alpha:
    display(f"Result: There is a statistically significant association between Academic Year and Knowledge Classification (p < {alpha}).")
else:
    display(f"Result: There is no statistically significant association between Academic Year and Knowledge Classification (p >= {alpha}).")
# Out:
# 'Observed Contingency Table (Academic Year vs. Knowledge Classification):'
# Knowledge_Classification  High knowledge  Low knowledge  Moderate knowledge
# Academic Year
# 1st year                              14              5                  20
# 2nd year                              21              2                  15
# 3rd year                              67              6                  43
# Final year                            51             11                  20
# '\nObserved Chi-square statistic: 14.29'
# 'Permutation Test P-value (approximating Fisher-Freeman-Halton): 0.0236'
# 'Result: There is a statistically significant association between Academic Year and Knowledge Classification (p < 0.05).'
